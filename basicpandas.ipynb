# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-3.0.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-3.0.1-cp313-cp313-win_amd64.whl (9.7 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/pandas/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /simple/pandas/
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: c:\Users\Dell\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Dell\Downloads\customers_data.csv') #read csv

# %%
# Inspecting the DataFrame

df.shape          # (rows, columns)
# Out:
# (100, 12)

# %%
df.head()         # First 5 rows
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
df.tail()         # Last 5 rows
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview        Sri Lanka       +1-846-706-2218
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        2022-01-30
# ...

# %%
df.columns        # List of column names
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='str')

# %%
df.info()         # Summary (dtypes, nulls)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Index              100 non-null    int64
#  1   Customer Id        100 non-null    str
#  2   First Name         100 non-null    str
#  3   Last Name          100 non-null    str
#  4   Company            100 non-null    str
#  5   City               100 non-null    str
#  6   Country            100 non-null    str
#  7   Phone 1            100 non-null    str
#  8   Phone 2            100 non-null    str
#  9   Email              100 non-null    str
#  10  Subscription Date  100 non-null    str
#  11  Website            100 non-null    str
# dtypes: int64(1), str(11)
# memory usage: 9.5 KB

# %%
  # Filter: Selects rows where 'City' is one of the listed values ('Delhi' OR 'Pune').

df[df['City'].isin(['Delhi', 'Pune'])]
# Out:
# Empty DataFrame
# Columns: [Index, Customer Id, First Name, Last Name, Company, City, Country, Phone 1, Phone 2, Email, Subscription Date, Website]
# Index: []

# %%
# --- Basic Selection ---

df['Email']                     # Selects one column by name (returns a Series).
# Out:
# 0           zunigavanessa@smith.info
# 1                    vmata@colon.com
# 2                beckycarr@hogan.com
# 3        stanleyblackwell@benson.org
# 4            colinalvarado@miles.net
#                    ...
# 95                  hhart@jensen.com
# 96                 vkemp@ferrell.com
# 97                  swagner@kane.org
# 98    mccarthystephen@horn-green.biz
# 99            colleen91@faulkner.biz
# Name: Email, Length: 100, dtype: str

# %%
df[['Company','City','Country']] # Selects multiple columns by name (returns a DataFrame).
# Out:
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ..                              ...                ...
# 95                        Carey LLC       East Richard
# 96            Ware, Burns and Oneal       New Bradview
# 97                    Schmitt-Jones         Ortegaland
# 98               Fitzgerald-Harrell    Lake Elijahview
# 99               Le, Nash and Cross          Judymouth
#
#                        Country
# 0                        Chile
# 1                     Djibouti
# 2          Antigua and Barbuda
# 3           Dominican Republic
# 4   Slovakia (Slovak Republic)
# ..                         ...
# 95                      Guyana
# 96                   Sri Lanka
# ...

# %%
# --- Label-Based Indexing (.loc) ---

df.loc[8]                           # Selects the row with the label '0'.
# Out:
# Index                                       9
# Customer Id                   C2dE4dEEc489ae0
# First Name                             Sheryl
# Last Name                              Meyers
# Company                        Browning-Simon
# City                             Robersonstad
# Country                                Cyprus
# Phone 1                     854-138-4911x5772
# Phone 2                   +1-448-910-2276x729
# Email                 mariokhan@ryan-pope.org
# Subscription Date                  2020-01-13
# Website              https://www.bullock.net/
# Name: 8, dtype: object

# %%
df.loc[0:2, ['Company', 'City']]        # Label-based slice: Rows 0 through 2, and columns
# Out:
#            Company               City
# 0  Rasmussen Group       East Leonard
# 1      Vega-Gentry  East Jimmychester
# 2    Murillo-Perry      Isabelborough

# %%
# --- Data Filtering (Conditional Selection) ---need to check with anwar bro 

df['date'] = pd.to_datetime(df['Subscription Date'])                        # Filter: Selects rows where 'Age' is greater than 25 (uses a boolean mask).
filtered_df = df[df['Subscription Date'] > '2010-10-03']

# %%
df[
    (df['Country'] == 'Sri lanka') &
    (df['City'] == 'East Leonard')
]                                               # Filter:  (multiple conditions require parentheses and '&').
# Out:
# Empty DataFrame
# Columns: [Index, Customer Id, First Name, Last Name, Company, City, Country, Phone 1, Phone 2, Email, Subscription Date, Website, date]
# Index: []

# %%
df[df['Country'].isin(['Chile', 'Oman'])]
# Out:
#     Index      Customer Id First Name Last Name             Company  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter     Rasmussen Group
# 15     16  8cad0b4CBceaeec    Miranda   Beasley  Singleton and Sons
# 83     84  78C06E9b6B3DF20       Chad  Davidson      Garcia-Jimenez
#
#                  City Country           Phone 1                Phone 2  \
# 0        East Leonard   Chile      229.077.5154       397.884.0519x718
# 15       Desireeshire    Oman  540.085.3135x185  +1-600-462-6432x21881
# 83  South Joshuashire    Oman        8275702958          (804)842-4715
#
#                         Email Subscription Date                        Website
# 0    zunigavanessa@smith.info        2020-08-24     http://www.stephenson.com/
# 15    vduncan@parks-hardy.com        2022-04-12             http://acosta.org/
# 83  justinwalters@jimenez.com        2021-11-15  http://www.garner-oliver.com/

# %%
df['Age'] = df['Age'] + 1                                       # Updates existing 'Age' column by adding 1 to every value.
df['Gender'].replace({'M':'Male', 'F': 'Female'}, inplace=True) # Replaces 'M' and 'F' values with full names in the 'Gender' column.

# %%
#Adding / Modifying Columns

df['Salary'] = pd.Series([50000, 60000, 55000, 70000])               # Adds new 'Salary' column from a list.
                              # Adds calculated 'Bonus' column (vectorized operation).

# %%
df.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website', 'Salary'],
#       dtype='str')

# %%
df.shape
# Out:
# (100, 13)

# %%
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
# Adds a Bonus column that is 10% of each person's Salary
df['Bonus'] = df['Salary'] * 0.10

# You can also add them together for a Total Pay column
df['Total_Pay'] = df['Salary'] + df['Bonus']

# %%
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
df['Salary'] = df['Salary'] + 7       

df.head()                                # Updates existing 'salary' column by adding 7 to every value.
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
# Replaces 'Srilanka' 
df['Country'].replace({'Srilanka':'Lankan'}, inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_19468\4057549128.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df['Country'].replace({'Srilanka':'Lankan'}, inplace=True)
# 0                          Chile
# 1                       Djibouti
# 2            Antigua and Barbuda
# 3             Dominican Republic
# ...

# %%
# Renames columns (modifies the DataFrame directly).
df.rename(columns={'Company':'Industry', 'City':'Location'}, inplace=True)

# %%
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                           Industry           Location  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
#deleting rows and columns:

df.drop('Bonus', axis=1, inplace=True)      # Drops the 'Bonus' column (axis=1) permanently (inplace=True).
df.drop(2, axis=0, inplace=True)            # Drops the row with index label '2' (axis=0) permanently.
# Reminder: axis=0 refers to rows, axis=1 refers to columns.

# %%
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
# 5      6  2d08FB17EE273F4      Aimee     Downs
#
#                           Industry           Location  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
# 5                     Steele Group      Chavezborough
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 3          Dominican Republic  001-808-617-6467x12895        +1-813-324-8756
# ...

# %%
#sorting data:
df.sort_values(by='Salary')                     # Sorts the DataFrame by the values in the 'Age' column (ascending is the default).
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# 5       6  2d08FB17EE273F4      Aimee     Downs
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                            Industry           Location  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# 5                      Steele Group      Chavezborough
# ...

# %%
df.sort_values(by='Salary', ascending=False) # Sorts the DataFrame by 'Salary' in descending order.
# Out:
#     Index      Customer Id First Name Last Name  \
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 4       5  053d585Ab6b3159     Joanna    Bender
# 5       6  2d08FB17EE273F4      Aimee     Downs
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                            Industry           Location  \
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 1                       Vega-Gentry  East Jimmychester
# 0                   Rasmussen Group       East Leonard
# 4          Martin, Lang and Andrade     West Priscilla
# 5                      Steele Group      Chavezborough
# ...
